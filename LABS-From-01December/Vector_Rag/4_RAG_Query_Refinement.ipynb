# %% [markdown]
# ##  Query Refinement Techniques in RAG pipelines
#
# Retrieval quality is the biggest factor influencing overall RAG performance.
#
#
# * Baseline retrieval embeds the query as-is and returns the top-K nearest documents, but this often fails for multi-topic or poorly phrased queries.
#
#
# * Some queries differ significantly from the language or structure of the source documents, leading to weak matches.
#
#
# * Query Refinement Techniquess help bridge these gaps and improve accuracy on more complex or ambiguous queries.
#
#     * Query Decomposition
#     * Query Expansion

# %%
import json
import numpy as np
from typing import List, Tuple

from langchain_text_splitters  import CharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
embeddings = OpenAIEmbeddings()



llm = ChatOpenAI(
    model="gpt-4o-mini"
)

# %% [markdown]
# ## Corpus — Load and Process Climate Change PDF

# %%
import os
# directory setup
# ------------------------------
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()

pdf_path = current_dir + "/data/Climate Change.pdf"    


print(pdf_path)
if not os.path.exists(pdf_path):
    raise FileNotFoundError("❌ dataset.csv not found in current directory.")
# Out:
# C:\Users\vyanktesh.l\Documents\FDE\FullStack\FDE_first_web_App\LABS-From-01December\Vector_Rag/data/Climate Change.pdf

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path: str) -> List[Document]:
    """Extract text from PDF and convert to LangChain Documents"""
    
    documents = []
    
    try:
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            
            for page_num, page in enumerate(pdf_reader.pages):
                text = page.extract_text()
                if text.strip():  # Only add non-empty pages
                    # Create metadata with page number
                    metadata = {
                        "source": pdf_path,
                        "page": page_num + 1,
                        "document": "Understanding Climate Change"
                    }
                    documents.append(Document(page_content=text, metadata=metadata))
                    
        print(f"✅ Extracted {len(documents)} pages from PDF")
        return documents
        
    except Exception as e:
        print(f"❌ Error reading PDF: {e}")
        return []

# Load the Climate Change PDF

climate_documents = extract_text_from_pdf(pdf_path)
# Out:
# ✅ Extracted 35 pages from PDF

# %%
# Convert documents to LangChain Document format

simple_documents = []
for doc in climate_documents:
    simple_documents.append(Document(
        page_content=doc.page_content,
        metadata=doc.metadata  # Preserve metadata if needed
    ))

print(f"📄 Converted {len(simple_documents)} documents")
langchain_documents = simple_documents
# Out:
# 📄 Converted 35 documents

# %% [markdown]
# ## Chunking

# %%
# Split the documents into chunks
text_splitter = CharacterTextSplitter(
    chunk_size=10000,
    chunk_overlap=100,
    separator="\n"
)
docs = text_splitter.split_documents(climate_documents)

print(f"🔪 Split into {len(docs)} chunks")
for i, doc in enumerate(docs):
    print(f"  Chunk {i+1}: {doc.page_content[:100]}...")
    print(f"     Metadata: {doc.metadata}\n")
# Out:
# 🔪 Split into 35 chunks
#   Chunk 1: By Nicholas SchneiderUnderstanding
# Climate Change...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 1, 'document': 'Understanding Climate Change'}
#
#   Chunk 2: U n d e r s t a n d i n g  C l i m a t e  C h a n g e Preface   . . . . . . . . . . . . . . . . . . ...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 3, 'document': 'Understanding Climate Change'}
#
#   Chunk 3: w w w . f r a s e r i n s t i t u t e . o r gCopyright © 2008 by The Fraser Institute. All rights
# r...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 4, 'document': 'Understanding Climate Change'}
#
#   Chunk 4: 1 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Global warming, climate change, and greenhou...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 5, 'document': 'Understanding Climate Change'}
#
#   Chunk 5: It is a challenge to summarize such a complex
# and evolving subject matter into one publication,
# bu...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 6, 'document': 'Understanding Climate Change'}
#
#   Chunk 6: About the author
# Nicholas Schneider is a former Policy Analyst with
# The Fraser Institute’s Centre f...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 7, 'document': 'Understanding Climate Change'}
#
#   Chunk 7: 4 w w w . f r a s e r i n s t i t u t e . o r gThe earth’s climate is a complex natural system of
# i...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 8, 'document': 'Understanding Climate Change'}
#
#   Chunk 8: 5 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Figure 2: A simplified representation of the...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 9, 'document': 'Understanding Climate Change'}
#
#   Chunk 9: 6 w w w . f r a s e r i n s t i t u t e . o r gCauses of climate change
# Climate can change due to fo...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 10, 'document': 'Understanding Climate Change'}
#
#   Chunk 10: 7 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Summary
# Climate generally refers to the aver...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 11, 'document': 'Understanding Climate Change'}
#
#   Chunk 11: 8 w w w . f r a s e r i n s t i t u t e . o r gClimate change and the earth’s
# energy balance
# The e...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 12, 'document': 'Understanding Climate Change'}
#
#   Chunk 12: 9 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Greenhouse gases
# Levels of different greenho...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 13, 'document': 'Understanding Climate Change'}
#
#   Chunk 13: 1 0 w w w . f r a s e r i n s t i t u t e . o r gChanges to the land surface
# The local climate, and ...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 14, 'document': 'Understanding Climate Change'}
#
#   Chunk 14: Anthropogenic
# -2 -1 0 1 2
# Radioactive Forcing (W m-2)high
# high
# Med
# Low
# Med-
# Low
# Med-
# Low
# Low
# Low
# Low...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 15, 'document': 'Understanding Climate Change'}
#
#   Chunk 15: 1 2 w w w . f r a s e r i n s t i t u t e . o r gChanges in temperatures
# observed on earth
# At any...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 16, 'document': 'Understanding Climate Change'}
#
#   Chunk 16: O b s e r v e d  C h a n g e s  i n  W e a t h e r  a n d
# C l i m a t e  o v e r  t h e  P a s t  ...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 17, 'document': 'Understanding Climate Change'}
#
#   Chunk 17: 1 4 w w w . f r a s e r i n s t i t u t e . o r gChanges in the earth’s
# other climate properties
# ...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 18, 'document': 'Understanding Climate Change'}
#
#   Chunk 18: 1 5 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Summary
# The available data imply an increa...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 19, 'document': 'Understanding Climate Change'}
#
#   Chunk 19: 16 w w w . f r a s e r i n s t i t u t e . o r gThe cryosphere  is the frozen part of the earth’s
# w...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 20, 'document': 'Understanding Climate Change'}
#
#   Chunk 20: 17 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Glaciers
# Glaciers are affected by changes i...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 21, 'document': 'Understanding Climate Change'}
#
#   Chunk 21: 18 w w w . f r a s e r i n s t i t u t e . o r gThe ocean plays an important role in climate
# varia...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 22, 'document': 'Understanding Climate Change'}
#
#   Chunk 22: 19 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Sea levels
# Two major processes change the g...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 23, 'document': 'Understanding Climate Change'}
#
#   Chunk 23: 20 w w w . f r a s e r i n s t i t u t e . o r gThe earliest records of weather and climate derived ...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 24, 'document': 'Understanding Climate Change'}
#
#   Chunk 24: 21 U n d e r s t a n d i n g  C l i m a t e  C h a n g e The earth is currently in an interglacial (...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 25, 'document': 'Understanding Climate Change'}
#
#   Chunk 25: 22 w w w . f r a s e r i n s t i t u t e . o r gOverall, the IPCC states that average Northern
# Hemi...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 26, 'document': 'Understanding Climate Change'}
#
#   Chunk 26: 23 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Summary
# Some aspects of current climate cha...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 27, 'document': 'Understanding Climate Change'}
#
#   Chunk 27: 24 w w w . f r a s e r i n s t i t u t e . o r gThe most complex climate models attempt to
# simulate...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 28, 'document': 'Understanding Climate Change'}
#
#   Chunk 28: 25 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Climate sensitivity: Climate sensitivity is...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 29, 'document': 'Understanding Climate Change'}
#
#   Chunk 29: 26 w w w . f r a s e r i n s t i t u t e . o r gThe climate is constantly changing, but the IPCC
# us...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 30, 'document': 'Understanding Climate Change'}
#
#   Chunk 30: Year1900 2000temperature Anomaly (0C)
# 1980 1960 1940 1920-1.0-0.50.00.51.0
# Santa Maria Agung el Chic...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 31, 'document': 'Understanding Climate Change'}
#
#   Chunk 31: 28 w w w . f r a s e r i n s t i t u t e . o r gThe IPCC report presents many specific forecasts
# of...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 32, 'document': 'Understanding Climate Change'}
#
#   Chunk 32: 29 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Sea levels: Depending on the emissions scen...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 33, 'document': 'Understanding Climate Change'}
#
#   Chunk 33: 3 0 w w w . f r a s e r i n s t i t u t e . o r gReferences
# De Laat, A.T.J. and A.N. Maurellis (2004...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 34, 'document': 'Understanding Climate Change'}
#
#   Chunk 34: About t he Fraser Institute
# Our vision is a free and prosperous world where
# individuals benefit fr...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 35, 'document': 'Understanding Climate Change'}
#
#   Chunk 35: The Fraser Institute,
# 4th Floor, 1770 Burrard Street
# Vancouver, British Columbia
# Canada  V6J 3G7
# h...
#      Metadata: {'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 36, 'document': 'Understanding Climate Change'}

# %% [markdown]
# ##  Create Vector Store with openai Embeddings

# %%
# Create the vector store
print("🔄 Creating vector store with openai embeddings...")
vector_store = Chroma.from_documents(
    documents=docs,
    embedding=embeddings,
    persist_directory="./db/chroma_db_climate"
)

print("✅ Vector store created successfully!")
# Out:
# 🔄 Creating vector store with openai embeddings...
# ✅ Vector store created successfully!

# %% [markdown]
# ## Base Retriever
#
# User: "What is the relationship between historical CO2 levels, temperature changes during ice age cycles, and the current projections for future warming based on climate models?"
#
# Step 1: Retrieve → "historical CO2 levels and patterns"
# Step 2: Retrieve → "temperature changes during ice age cycles"
# Step 3: Retrieve → "current CO2 levels and trends"
# Step 4: "climate model projections for future warming"

# %%
# Create base retriever
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# Test base retrieval
question = 'What is the relationship between historical CO2 levels, temperature changes during ice age cycles, and the current projections for future warming based on climate models?'
base_results = retriever.invoke(question)

# %%
base_results
# Out:
# [Document(metadata={'document': 'Understanding Climate Change', 'page': 24, 'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf'}, page_content='20 w w w . f r a s e r i n s t i t u t e . o r gThe earliest records of weather and climate derived \nfrom modern instruments such as thermometers \ngo back only to about 1750. Palaeoclimate science \ntherefore looks to long-term natural records to  \nestimate past climate changes. Many organisms, \nsuch as trees, coral, and plankton, exhibit variations \nin growth due to changes in the local climate,  \nproviding a possible means of inferring local \nchanges in the distant past. Non-biological natural \nrecords, such as ice-cores, can also help in the  \nestimation of past climate change. \nMany million years ago \nFor most of the last 500 million years, the earth \nwas probably much warmer than it is today  \nand had no ice sheets. Palaeoclimate records of \natmospheric CO 2 levels indicate that CO 2 varied \nwidely due to tectonic changes, including volcanic \nactivity. About three million years ago, sea levels \nare estimated to have been about 15 to 25 meters \nhigher than they are today. the past few million years\nOver the past three million years, climate change has \nbeen dominated by 100,000 year cycles that shift \nbetween long glacial periods, or ice ages, and brief, \nwarmer interglacial periods. These cycles are linked to \nchanges in the earth’s orbit around the sun. \n \nFigure 6: Indicators of climate change over the last 750,000 years  \nSource: Jouzel et al. (2004)\nAtmospheric CO 2 levels tend to rise and fall with \nchanges in temperature. The CO 2 levels, however, \ndo not start to rise until several hundred years after \ntemperatures increase, which suggests that CO 2  \nincreases responded to temperature changes, but \nwere not the cause of the initial temperature increase.P a l e o c l i m a t e  E s t i m a t e s  \no f  P a s t  T e m p e r a t u r e sC h Ap t e R~ 6\nthousands of Years Ago\n700 600 500 400 300 200 100 0Cold \nGlacialWarm  \nInterglacial'),
#  Document(metadata={'document': 'Understanding Climate Change', 'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 33}, page_content='29 U n d e r s t a n d i n g  C l i m a t e  C h a n g e Sea levels: Depending on the emissions scenario, \nthe average sea level is projected to rise between \n18 cm and 59 cm. This will be due mostly to thermal \nexpansion, though melting of glaciers, ice caps,  \nand the Greenland ice sheet is also projected to \ncontribute to the rise. \nTropical cyclones: Models that examine tropical \ncyclones on a large scale predict a decrease in the \ntotal number of tropical cyclones and little to no \nchange in the intensity (strength) of individual  \ncyclones on average. On the other hand, models \nthat examine tropical cyclones at a higher resolution \nand on a smaller scale project that tropical cyclones \nwill become more intense. \nRegional Climate projections\nNew sources of uncertainty and complexity arise \nwhen attempting to project climate changes at local \nand regional levels. General projections of regional \nchanges are summarized in the IPCC report;  \nhowever, at this time, the uncertainties in regional \nprojections are substantial. See Chapter 11 of  \nthe full IPCC report for details of the regional  \nprojections and their limitations. Summary\nProjections are useful for understanding how much, \nand in what ways, the climate may change in the \nfuture as greenhouse gas emissions continue to rise. \nGenerally, climate models project an increase in  \naverage temperatures and sea levels, and a decrease \nin the cryosphere. Projections for smaller-scale \nand rare events are less certain, and more research \nis needed to improve the reliability of regional \nclimate projections.'),
#  Document(metadata={'document': 'Understanding Climate Change', 'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 6}, page_content='It is a challenge to summarize such a complex \nand evolving subject matter into one publication, \nbut for the benefit of the reader, this publication \npresents evidence to support the following brief \nconclusion:\nThe climate is naturally variable. Evidence shows \nthat throughout earth’s history, there have been  \nnumerous global climate changes that were much \nlarger than those experienced in recent times. For \nmost of the last 500 million years, the earth was \nprobably much warmer than it is today.Some data suggest that an increase has occurred \nin average temperatures at the earth’s surface of as \nmuch as 1°C since the mid-1800s, with continued trends \nof about one to two tenths of a degree per decade in \nrecent years. There are considerable uncertainties  \nand ongoing scientific debate about the reasons for \nsuch changes and what they mean for the future. \nComputer-run climate models used by the IPCC  \nassign most of the cause for this trend to increases  \nin the atmospheric concentrations of greenhouse \ngases, due mainly to the burning of fossil fuels. \nWhile predictions of climate change 50 or 100 years \nfrom now cannot be reliably made, it is plausible \nthat further increases in greenhouse gas levels this \ncentury will have an overall warming influence on \nthe climate. But it remains difficult to say how strong \nthe effect will be. The main effect predicted by climate \nmodels as a result of greenhouse gas emissions is a \nstrong warming in the mid-layer of the atmosphere \nover the tropics, and this has not been observed in \ndata to date. If warming at the surface occurs, some \nscenarios imply effects on sea levels, ice and snow \ntrends, precipitation, storminess, and many other \nclimate properties, though local effects in particular \nregions are too difficult to forecast reliably. \n2 w w w . f r a s e r i n s t i t u t e . o r g'),
#  Document(metadata={'document': 'Understanding Climate Change', 'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf', 'page': 32}, page_content='28 w w w . f r a s e r i n s t i t u t e . o r gThe IPCC report presents many specific forecasts \nof changes in the earth’s weather patterns over the \nnext 100 years, based on the assumption of strong \ngreenhouse gas-induced warming. \nGlobal climate projections\nTemperature: Depending on which of several \nscenarios of future global greenhouse gas  \nconcentrations is used, climate models project  \nthat average temperatures could increase from a \nminimum of 1.1ºC to a maximum of 6.4ºC.\nThe same models also predict that greenhouse gases \nwill cause warming in the tropical troposphere to \nbe about double the warming at the surface. As of \nthe present, this has not been observed. In most \navailable data series, the troposphere appears to be \nwarming less than the surface. Precipitation: Evaporation and precipitation are \nexpected to increase in a warmer climate. The \nmodels predict that precipitation will increase in \nthe tropics and at the poles, and decrease in the \nsubtropics and middle latitudes. The intensity of \nprecipitation is projected to increase, particularly in \ntropical areas and at the poles. \nSnow and ice: Current models show a wide \nrange in the response of Northern Hemisphere \nsea ice to temperature increases, from very little \nchange to a strong accelerating reduction over \nthe 21st century. Antarctic sea ice is projected to \ndecrease more slowly than in the Arctic.\nModels project an overall decrease in glacier  \nvolume, but there is uncertainty in how to estimate \nfuture changes. \nIn general, snow cover area and the total amount \nof snow is projected to decrease in the Northern \nHemisphere, with increases in a few regions.G l o b a l  a n d  R e g i o n a l \nC l i m a t e  P r o j e c t i o n sC h Ap t e R~ 9'),
#  Document(metadata={'document': 'Understanding Climate Change', 'page': 25, 'source': 'C:\\Users\\vyanktesh.l\\Documents\\FDE\\FullStack\\FDE_first_web_App\\LABS-From-01December\\Vector_Rag/data/Climate Change.pdf'}, page_content='21 U n d e r s t a n d i n g  C l i m a t e  C h a n g e The earth is currently in an interglacial (warm) \nperiod. During the previous interglacial, about \n100,000 years ago, there was less ice than now and \ntemperatures were likely warmer than at present. \nSea levels were about four to six meters higher  \nduring this last interglacial, mostly due to the melting \nof Greenland and Antarctic ice.\nAnother aspect of the current climate that is different \nfrom past interglacial periods is that atmospheric \nconcentrations of carbon dioxide, methane, and \nnitrous oxide (three greenhouse gases) are now \nhigher than in the past 650,000 years.\nthe past 10,000 years\nThe current interglacial is called the Holocene, \nwhich started about 11,500 years ago. During this \ntime, there were periods when regional, and possibly \nglobal, average temperatures were higher than \nnow. Temperatures in the Northern Hemisphere \nare estimated to have been higher than they are  \nat present for a long interval between 5,000 and \n7 ,000 years ago. temperature changes over the \npast millennium\nEvidence points to a warm interval in the medieval \nera (900-1300 AD) followed by the so-called Little \nIce Age, which lasted into the mid-1800s. Numerous \nstudies have found evidence of local temperatures \nthat were as warm or warmer in the medieval era \nthan in the current era. There have been many \nrecent attempts to estimate hemispheric and global \naverages of surface temperatures using paleoclimate  \ndata. Figure 7 shows several of these recent estimates \nof temperature changes in the Northern Hemisphere \nover the last 1,300 years.')]

# %% [markdown]
# ## Custom Query variants - - Multiple retrieval rounds with dependency between steps.
#
# Goal: Improve retrieval quality by enhancing the original query.
# How it works:
#
#     Generate multiple query variations from original
#     Search with all variations simultaneously
#     Single retrieval process with enriched context

# %%
def break_into_subquestions(complex_question: str) -> List[str]:
    """Break down complex climate questions into dependent sub-questions"""
    
    prompt_template = """Analyze this complex climate science question and break it into 3-4 logical sub-questions that need to be answered in sequence.
    Each sub-question should build upon the previous one, creating a step-by-step reasoning chain.

    Complex Question: {question}

    Return ONLY a numbered list of sub-questions without any additional text. Make each sub-question specific and answerable.

    Sub-questions:"""
    
    prompt = ChatPromptTemplate.from_template(prompt_template)
    chain = prompt | llm
    
    try:
        response = chain.invoke({"question": complex_question})
        subquestions_text = response.content
        
        # Parse numbered sub-questions
        subquestions = []
        for line in subquestions_text.split('\n'):
            line = line.strip()
            # Match lines that start with numbers (1., 2., etc.)
            if line and (line[0].isdigit() and '.' in line.split()[0]):
                # Remove the number and period
                subq = line.split('.', 1)[1].strip()
                if subq and len(subq) > 10:  # Ensure meaningful questions
                    subquestions.append(subq)
        
        print("🔍 Multi-hop sub-questions generated:")
        for i, subq in enumerate(subquestions):
            print(f"  Step {i+1}: {subq}")
            
        return subquestions
        
    except Exception as e:
        print(f"Error generating sub-questions: {e}")
        return generate_fallback_subquestions(complex_question)

# %%
question="What is the relationship between historical CO2 levels, temperature changes during ice age cycles, and the current projections for future warming based on climate models?"
# Generate query subquestions
query_variants = break_into_subquestions(question)
# Out:
# 🔍 Multi-hop sub-questions generated:
#   Step 1: What were the historical CO2 levels during past ice age cycles, and how did they correlate with temperature changes?
#   Step 2: How did the changes in temperature during these ice age cycles influence atmospheric CO2 levels?
#   Step 3: What are the key mechanisms by which current climate models project future warming based on historical CO2 and temperature data?
#   Step 4: How do current projections for future warming compare to the temperature changes observed during past ice age cycles in light of historical CO2 levels?

# %% [markdown]
# ## Query Decomposition
# Complex queries can be improved by breaking them into smaller sub-questions, each with its own targeted retrieval step.
#
# Query decomposition generates either the original question or a set of simpler, focused questions.
#
# The model drives this process using a system prompt that defines the task and guides behavior.
#
# Providing few-shot examples strengthens the model’s generalization, while removing them leads to less reliable decompositions.

# %%
from pydantic import BaseModel, Field
from langchain_core.output_parsers import PydanticToolsParser
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
    RunnableBranch,
)

# %%
decomp_system_prompt = """You are a expert assistant that prepares queries that will be sent to a search component. 
These queries may be very complex. Your job is to simplify complex queries into multiple queries that can be answered in isolation to eachother.

If the query is simple, then keep it as it is.

If there are acronyms or words you are not familiar with, do not try to rephrase them.
Here is an example of how to respond in a standard interaction:
<example>
- Query: Did Meta or Nvidia make more money last year?
Decomposed Questions: [SubQuery(sub_query='How much profit did Meta make last year?'), SubQuery(sub_query'How much profit did Nvidia make last year?')]
</example>
<example>
- Query: What is the capital of France?
Decomposed Questions: [SubQuery(sub_query='What is the capital of France?')]
</example>"""

# %%
class SubQuery(BaseModel):
    """You have performed query decomposition to generate a subquery of a question"""

    sub_query: str = Field(description="A unique subquery of the original question.")

# %%
query_decomposition_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", decomp_system_prompt),
        ("human", "Here is the customer's question: <question>{question}</question> How do you answer to the instructions?"),
    ]
)

llm_with_tools = llm.bind_tools([SubQuery])
decomp_query_analyzer = query_decomposition_prompt | llm_with_tools | PydanticToolsParser(tools=[SubQuery])

# %%
queries = decomp_query_analyzer.invoke({"question": question})
queries
# Out:
# [SubQuery(sub_query='What is the relationship between historical CO2 levels and temperature changes during ice age cycles?'),
#  SubQuery(sub_query='What are the current projections for future warming based on climate models?')]

# %% [markdown]
# ## Query Expansion
#
# Query expansion improves retrieval by generating multiple alternative versions of the original query.
#
# Unlike decomposition, expansion keeps the same intent but varies the wording to increase match likelihood.
#
# The model uses a system prompt that instructs it to produce multiple rewrites of the query.
#
# In our setup, the prompt consistently returns three distinct reformulations of the original question.

# %%
class ParaphrasedQuery(BaseModel):
    """You have performed query expansion to generate a paraphrasing of a question."""

    paraphrased_query: str = Field(description="A unique paraphrasing of the original question.")

# %%
paraphrase_system_prompt = """You are an expert at converting user questions into database queries. 
You have access to a database of travel destinations and a list of recent destinations for travelers. 

Perform query expansion. If there are multiple common ways of phrasing a user question 
or common synonyms for key words in the question, make sure to return multiple versions 
of the query with the different phrasings.

If there are acronyms or words you are not familiar with, do not try to rephrase them.

Always return at least 3 versions of the question."""

# %%
query_expansion_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", paraphrase_system_prompt),
        ("human", "Here is the customer's question: <question>{question}</question> How do you answer to the instructions?"),
    ]
)
llm_with_tools = llm.bind_tools([ParaphrasedQuery])
query_expansion = query_expansion_prompt | llm_with_tools | PydanticToolsParser(tools=[ParaphrasedQuery])

# %%
short_question="co2 levels"

# %%
query_expansion.invoke({"question": short_question})
# Out:
# [ParaphrasedQuery(paraphrased_query='What are the levels of CO2?'),
#  ParaphrasedQuery(paraphrased_query='Can you provide information on CO2 concentrations?'),
#  ParaphrasedQuery(paraphrased_query='What is the current status of carbon dioxide levels?')]
